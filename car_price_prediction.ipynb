# %% [markdown]
# <a href="https://colab.research.google.com/github/Neree2/test/blob/main3/car_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
URL='https://raw.githubusercontent.com/wanjantp/dataset/main/car_data.csv'
df=pd.read_csv(URL)

# %%
df.shape
# Out:
# (301, 9)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
X=df.drop('Selling_Price',axis=1)
y=df['Selling_Price']

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()
enc.fit(X[['Car_Name','Fuel_Type','Seller_Type','Transmission']])
X[['Car_Name','Fuel_Type','Seller_Type','Transmission']] = enc.transform(df[['Car_Name','Fuel_Type','Seller_Type','Transmission']])

# %%
X
# Out:
#      Car_Name  Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0        90.0  2014           5.59       27000        2.0          0.0
# 1        93.0  2013           9.54       43000        1.0          0.0
# 2        68.0  2017           9.85        6900        2.0          0.0
# 3        96.0  2011           4.15        5200        2.0          0.0
# 4        92.0  2014           6.87       42450        1.0          0.0
# ..        ...   ...            ...         ...        ...          ...
# 296      69.0  2016          11.60       33988        1.0          0.0
# 297      66.0  2015           5.90       60000        2.0          0.0
# 298      69.0  2009          11.00       87934        2.0          0.0
# 299      69.0  2017          12.50        9000        1.0          0.0
# 300      66.0  2016           5.90        5464        2.0          0.0
#
#      Transmission  Owner
# 0             1.0      0
# 1             1.0      0
# 2             1.0      0
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=49)

# %%
# Standardization, or mean removal and variance scaling
# Standardization of datasets is a common requirement for many machine learning
# estimators implemented in scikit-learn; they might behave badly if the
# individual features do not more or less look like standard normally distributed data:
# Gaussian with zero mean and unit variance.

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Fit only to the training data
scaler.fit(X_train)

# Now apply the transformations to the data:
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
#11302

from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=11302)
#1
from sklearn.ensemble import RandomForestRegressor
#2
model=RandomForestRegressor(max_depth=14)
#4
model.fit(X_train, y_train)
#5
y_pred = model.predict(X_test)

from sklearn.metrics import r2_score
a=r2_score(y_test, y_pred)
print(a)
# Out:
# 0.9792804118466623

# %%
#11302

from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.21, random_state=6)
#1
from sklearn.ensemble import RandomForestRegressor
#2
model=RandomForestRegressor(n_estimators=888,max_depth=14,max_leaf_nodes=956,max_samples=237)
#4
model.fit(X_train, y_train)
#5
y_pred = model.predict(X_test)

from sklearn.metrics import r2_score
a=r2_score(y_test, y_pred)
print(a)
# Out:
# 0.9767760452707963

# %%
import random
#11302
a=0
from sklearn.model_selection import train_test_split

while a<=0.98:
  num=random.randint(1,231)
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=6)
  #1
  from sklearn.ensemble import RandomForestRegressor
  #2
  model=RandomForestRegressor(n_estimators=888,max_depth=14,max_leaf_nodes=956,max_samples=num)
  #4
  model.fit(X_train, y_train)
  #5
  y_pred = model.predict(X_test)

  from sklearn.metrics import r2_score
  a=r2_score(y_test, y_pred)
  print(a)
  print(num)
# Out:
# 0.9683734066014698
# 144
# 0.9743445829829235
# 208
# 0.956232654581153
# 90
# 0.9710600990456912
# 182
# 0.679547254927864
# 9
# 0.9581119985780361
# 94
# 0.9681021316425775
# 143
# 0.9716051196165784
# 172
# 0.6593674928607114
# 8
# 0.9584660781436549
# 100
# 0.9615852506840147
# 99
# 0.9124190277495707
# 38
# 0.9297227197912893
# 47
# 0.9432480021456267
# 67
# 0.9515509417303891
# 78
# 0.9323981075250816
# 49
# 0.9538925193394578
# 82
# 0.9717653491429833
# 196
# 0.9718349754027583
# 200
# 0.7876603786985401
# 14
# 0.9634933085606612
# 116
# 0.9389742144781198
# 62
# 0.9537748794760821
# 81
# 0.9726656376170163
# 193
# 0.9517377633969824
# 81
# 0.9722182165303614
# 191
# 0.9718126538606718
# 177
# 0.9675203306247057
# 139
# 0.9649424849960895
# 121
# 0.96934677111748
# 157
# 0.9508952918498504
# 78
# 0.9723170219746139
# 195
# 0.9733338099434372
# 219
# 0.9591112912011768
# 102
# 0.9744175436237278
# 229
# 0.9683795022469258
# 143
# 0.9635643249415355
# 132
# 0.7965831117433841
# ...

# %%
import random
#11302
a=0
from sklearn.model_selection import train_test_split

while a<=0.988:
  num=random.randint(1,100000)
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.21, random_state=num)
  #1
  from sklearn.ensemble import RandomForestRegressor
  #2
  model=RandomForestRegressor()
  #4
  model.fit(X_train, y_train)
  #5
  y_pred = model.predict(X_test)

  from sklearn.metrics import r2_score
  a=r2_score(y_test, y_pred)
  print(a)
  print(num)
# Out:
# 0.9593265318116752
# 10039
# 0.9246832432192
# 41096
# 0.9731619951749308
# 16711
# 0.8355340629733503
# 24163
# 0.922189107799484
# 16917
# 0.9693673606438796
# 82163
# 0.9706166457933059
# 61156
# 0.8620507105091133
# 74468
# 0.9146788491134721
# 90266
# 0.9738520283889978
# 11844
# 0.9785881876634231
# 27579
# 0.7943399616216829
# 98501
# 0.8382413267339337
# 86157
# 0.9718885244477201
# 67279
# 0.9270369695596717
# 65665
# 0.9649232468325646
# 8042
# 0.917156269302516
# 96671
# 0.8266708610579361
# 25737
# 0.9045722476673879
# 59576
# 0.8382565557153652
# 39925
# 0.9601782694652206
# 69509
# 0.8747678387144635
# 17582
# 0.8524698110485224
# 35881
# 0.9421834986406264
# 78625
# 0.8416128206794204
# 5035
# 0.9605745283830216
# 11656
# 0.9356617085200639
# 38414
# 0.9722203672757528
# 1017
# 0.8834510908103833
# 14848
# 0.9334547401799762
# 52926
# 0.9032754212650052
# 70115
# 0.9709616556136265
# 56890
# 0.9816209686317514
# 75166
# 0.9675910347611654
# 74190
# 0.9452647832475309
# ...

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=49)

from sklearn import tree
model2=tree.DecisionTreeRegressor()
#4
model2.fit(X_train, y_train)
#5
y_pred = model2.predict(X_test)

from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.954781192347609

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=49)

from sklearn.ensemble import GradientBoostingRegressor
model3=GradientBoostingRegressor()
#4
model3.fit(X_train, y_train)
#5
y_pred = model3.predict(X_test)

from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9566370140521577

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=49)

from sklearn.neural_network import MLPRegressor
model4=MLPRegressor()
#4
model4.fit(X_train, y_train)
#5
y_pred = model4.predict(X_test)

from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# -258.7572764891243

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=49)

from sklearn.multioutput import MultiOutputRegressor
model4=MLPRegressor()
#4
model4.fit(X_train, y_train)
#5
y_pred = model4.predict(X_test)

from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
